# %% [markdown]
# # lab2

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ntia340/Mental_Health_Care_in_the_Last_4_Weeks.csv')
df.head()
# Out:
#                                            Indicator   Group          State  \
# 0       Received Counseling or Therapy, Last 4 Weeks  By Sex  United States
# 1       Received Counseling or Therapy, Last 4 Weeks  By Sex  United States
# 2  Needed Counseling or Therapy But Did Not Get I...  By Sex  United States
# 3  Took Prescription Medication for Mental Health...  By Age  United States
# 4  Took Prescription Medication for Mental Health...  By Age  United States
#
#         Subgroup Phase  Time Period           Time Period Label  \
# 0           Male     2           15       Sep 16 - Sep 28, 2020
# 1         Female     2           15       Sep 16 - Sep 28, 2020
# 2         Female    -1            1  Dec 22, 2020 - Jan 5, 2021
# 3  50 - 59 years    -1            1       Mar 30 - Apr 13, 2021
# 4  60 - 69 years    -1            1       Mar 30 - Apr 13, 2021
#
#   Time Period Start Date Time Period End Date  Value  LowCI  HighCI  \
# ...

# %%
df.head()
# Out:
#                                            Indicator   Group          State  \
# 0       Received Counseling or Therapy, Last 4 Weeks  By Sex  United States
# 1       Received Counseling or Therapy, Last 4 Weeks  By Sex  United States
# 2  Needed Counseling or Therapy But Did Not Get I...  By Sex  United States
# 3  Took Prescription Medication for Mental Health...  By Age  United States
# 4  Took Prescription Medication for Mental Health...  By Age  United States
#
#         Subgroup Phase  Time Period           Time Period Label  \
# 0           Male     2           15       Sep 16 - Sep 28, 2020
# 1         Female     2           15       Sep 16 - Sep 28, 2020
# 2         Female    -1            1  Dec 22, 2020 - Jan 5, 2021
# 3  50 - 59 years    -1            1       Mar 30 - Apr 13, 2021
# 4  60 - 69 years    -1            1       Mar 30 - Apr 13, 2021
#
#   Time Period Start Date Time Period End Date  Value  LowCI  HighCI  \
# ...

# %%
df.shape
# Out:
# (10404, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10404 entries, 0 to 10403
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Indicator               10404 non-null  object
#  1   Group                   10404 non-null  object
#  2   State                   10404 non-null  object
#  3   Subgroup                10404 non-null  object
#  4   Phase                   10404 non-null  object
#  5   Time Period             10404 non-null  int64
#  6   Time Period Label       10404 non-null  object
#  7   Time Period Start Date  10404 non-null  object
#  8   Time Period End Date    10404 non-null  object
#  9   Value                   9914 non-null   float64
#  10  LowCI                   9914 non-null   float64
#  11  HighCI                  9914 non-null   float64
#  12  Confidence Interval     9914 non-null   object
#  13  Quartile Range          6732 non-null   object
# ...

# %%
df.describe()
# Out:
#         Time Period        Value        LowCI       HighCI  Suppression Flag
# count  10404.000000  9914.000000  9914.000000  9914.000000              22.0
# mean      28.134948    17.450736    14.771565    20.475661               1.0
# std       11.040210     8.270565     7.659396     9.052521               0.0
# min        1.000000     1.400000     0.800000     2.000000               1.0
# 25%       20.000000    10.300000     8.000000    12.900000               1.0
# 50%       29.000000    16.200000    13.900000    19.200000               1.0
# 75%       37.000000    24.000000    20.800000    27.400000               1.0
# max       45.000000    62.900000    53.200000    71.900000               1.0

# %% [markdown]
#  # I have 5 rows and 15 columns
#
#  # Numeric Columns: Value, HighCI, LowCI, Suppression Flag, Time Period, Confidence Interval, Phase
#
#  # Categorical Columns: Subgroup, Indicator, Group, state
#
#  # First impressions: Data had a wide demographics for people who didn't recieve counseling and people who did recieve it. There was an indciator for people who took medication for their treatment

# %%
df = df.rename(columns={"Indicator":"Index" }) 
df.head()
# Out:
#                                                Index   Group          State  \
# 0       Received Counseling or Therapy, Last 4 Weeks  By Sex  United States
# 1       Received Counseling or Therapy, Last 4 Weeks  By Sex  United States
# 2  Needed Counseling or Therapy But Did Not Get I...  By Sex  United States
# 3  Took Prescription Medication for Mental Health...  By Age  United States
# 4  Took Prescription Medication for Mental Health...  By Age  United States
#
#         Subgroup Phase  Time Period           Time Period Label  \
# 0           Male     2           15       Sep 16 - Sep 28, 2020
# 1         Female     2           15       Sep 16 - Sep 28, 2020
# 2         Female    -1            1  Dec 22, 2020 - Jan 5, 2021
# 3  50 - 59 years    -1            1       Mar 30 - Apr 13, 2021
# 4  60 - 69 years    -1            1       Mar 30 - Apr 13, 2021
#
#   Time Period Start Date Time Period End Date  Value  LowCI  HighCI  \
# ...

# %%
df.isnull().sum()
# Out:
# Index                         0
# Group                         0
# State                         0
# Subgroup                      0
# Phase                         0
# Time Period                   0
# Time Period Label             0
# Time Period Start Date        0
# Time Period End Date          0
# Value                       490
# LowCI                       490
# HighCI                      490
# Confidence Interval         490
# Quartile Range             3672
# Suppression Flag          10382
# dtype: int64

# %%
df['LowCI'] # keep specific columns
# Out:
# 0         6.5
# 1        10.4
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 10399     7.1
# 10400    12.5
# 10401     6.6
# 10402     8.5
# 10403     8.6
# Name: LowCI, Length: 10404, dtype: float64

# %%
df.sort_values(by='Time Period')
# Out:
#                                                          Index     Group  \
# Time Period
# 1                 Received Counseling or Therapy, Last 4 Weeks    By Age
# 1                 Received Counseling or Therapy, Last 4 Weeks    By Age
# 1                 Received Counseling or Therapy, Last 4 Weeks    By Age
# 1                 Received Counseling or Therapy, Last 4 Weeks    By Age
# 1                 Received Counseling or Therapy, Last 4 Weeks    By Age
# ...                                                        ...       ...
# 45           Needed Counseling or Therapy But Did Not Get I...  By State
# 45           Needed Counseling or Therapy But Did Not Get I...  By State
# 45           Needed Counseling or Therapy But Did Not Get I...  By State
# 45           Needed Counseling or Therapy But Did Not Get I...  By State
# 45           Needed Counseling or Therapy But Did Not Get I...  By State
#
#                      State       Subgroup Phase           Time Period Label  \
# ...

# %%
df[0:5]
# Out:
#                                                Index   Group          State  \
# 0       Received Counseling or Therapy, Last 4 Weeks  By Sex  United States
# 1       Received Counseling or Therapy, Last 4 Weeks  By Sex  United States
# 2  Needed Counseling or Therapy But Did Not Get I...  By Sex  United States
# 3  Took Prescription Medication for Mental Health...  By Age  United States
# 4  Took Prescription Medication for Mental Health...  By Age  United States
#
#         Subgroup Phase  Time Period           Time Period Label  \
# 0           Male     2           15       Sep 16 - Sep 28, 2020
# 1         Female     2           15       Sep 16 - Sep 28, 2020
# 2         Female    -1            1  Dec 22, 2020 - Jan 5, 2021
# 3  50 - 59 years    -1            1       Mar 30 - Apr 13, 2021
# 4  60 - 69 years    -1            1       Mar 30 - Apr 13, 2021
#
#   Time Period Start Date Time Period End Date  Value  LowCI  HighCI  \
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Group', 'State', 'Subgroup', 'Phase', 'Time Period Label',
#        'Time Period Start Date', 'Time Period End Date', 'Value', 'LowCI',
#        'HighCI', 'Confidence Interval', 'Quartile Range', 'Suppression Flag'],
#       dtype='object')

# %%
df.loc[1]
# Out:
#                                                          Index  \
# Time Period
# 1            Needed Counseling or Therapy But Did Not Get I...
# 1            Took Prescription Medication for Mental Health...
# 1            Took Prescription Medication for Mental Health...
# 1            Took Prescription Medication for Mental Health...
# 1            Took Prescription Medication for Mental Health...
# ...                                                        ...
# 1            Needed Counseling or Therapy But Did Not Get I...
# 1            Needed Counseling or Therapy But Did Not Get I...
# 1            Needed Counseling or Therapy But Did Not Get I...
# 1            Needed Counseling or Therapy But Did Not Get I...
# 1            Needed Counseling or Therapy But Did Not Get I...
#
#                             Group          State  \
# Time Period
# 1                          By Sex  United States
# 1                          By Age  United States
# ...

# %% [markdown]
# # I selected the time period column and sorted the rows by one column and slicing it into  4 rows. It showed the output of the time period and the index.

# %%
df.hist(layout=(2,2), figsize=(10, 5), sharey=False, sharex=False, bins=50)
# Out:
# array([[<Axes: title={'center': 'Value'}>,
#         <Axes: title={'center': 'LowCI'}>],
#        [<Axes: title={'center': 'HighCI'}>,
#         <Axes: title={'center': 'Suppression Flag'}>]], dtype=object)

# %% [markdown]
# This group data shows 4 histograms focusing on different columns(HighCI, Supression Flag, Value, and LowCI)
# The Value, High and Low CI both share a a similar pattern with a rapid spike in the 10-20 range. and the suppression flag can be see as an outlier.

# %%
sum_values_by_subgroup = df.groupby("Index")["LowCI"].sum()
sum_values_by_subgroup.nlargest(10).plot.bar(figsize=(10,6), title="Top 10 Subgroups by Total Value")
# Out:
# <Axes: title={'center': 'Top 10 Subgroups by Total Value'}, xlabel='Index'>

# %% [markdown]
# # This bar graph shows the index on the x axis and the value on the y axis. It hard to find the pattern but there is large value for the people
# # who took prescription medicine and low value for the counseling part.
